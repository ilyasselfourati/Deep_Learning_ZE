# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from tensorflow import keras

# %%
(x_train, y_train), (x_test, y_test) = keras.datasets.mnist.load_data()

print("Dimensions de x_train :", x_train.shape)
print("Dimensions de y_train :", y_train.shape)
print("Dimensions de x_test  :", x_test.shape)
print("Dimensions de y_test  :", y_test.shape)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 [==============================] - 25s 2us/step
# Dimensions de x_train : (60000, 28, 28)
# Dimensions de y_train : (60000,)
# Dimensions de x_test  : (10000, 28, 28)
# Dimensions de y_test  : (10000,)

# %%
min_x_train = x_train.min()
max_x_train = x_train.max()

print("Min de x_train :", min_x_train)
print("Max de x_train :", max_x_train)

x_train_norm = (x_train-min_x_train)/(max_x_train-min_x_train)
x_test_norm = (x_test-min_x_train)/(max_x_train-min_x_train)
# Out:
# Min de x_train : 0
# Max de x_train : 255

# %%
num_row = 4
num_col = 6
num = num_row * num_col

images = x_train[:num]
labels = y_train[:num]

fig, axes = plt.subplots(num_row, num_col, figsize=(1.5*num_col,2*num_row))
for i in range(num):
    ax = axes[i//num_col, i%num_col]
    ax.imshow(images[i], cmap='gray')
    ax.set_title('Label : {}'.format(labels[i]))
plt.tight_layout()
plt.show()

# %%
num_layer1 = 100
num_layer2 = 100

model = keras.Sequential([
    keras.layers.Input((28,28), name='Input_layer'),
    keras.layers.Flatten(),
    keras.layers.Dense(num_layer1, activation='relu', name='Hidden_layer1'),
    keras.layers.Dense(num_layer2, activation='relu', name='Hidden_layer2'),
    keras.layers.Dense(10, activation='softmax', name='Output_layer')
])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten (Flatten)           (None, 784)               0
#
#  Hidden_layer1 (Dense)       (None, 100)               78500
#
#  Hidden_layer2 (Dense)       (None, 100)               10100
#
#  Output_layer (Dense)        (None, 10)                1010
#
# =================================================================
# Total params: 89,610
# Trainable params: 89,610
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %%
hist = model.fit(x_train,
                 y_train,
                 batch_size=500,
                 epochs=20,
                 validation_split=0.2)
# Out:
# Epoch 1/20
# 96/96 [==============================] - 2s 12ms/step - loss: 7.5143 - accuracy: 0.7783 - val_loss: 1.6186 - val_accuracy: 0.8809
# Epoch 2/20
# 96/96 [==============================] - 1s 9ms/step - loss: 1.2182 - accuracy: 0.8959 - val_loss: 1.0834 - val_accuracy: 0.9003
# Epoch 3/20
# 96/96 [==============================] - 1s 8ms/step - loss: 0.7365 - accuracy: 0.9180 - val_loss: 0.8403 - val_accuracy: 0.9140
# Epoch 4/20
# 96/96 [==============================] - 1s 9ms/step - loss: 0.4953 - accuracy: 0.9353 - val_loss: 0.7026 - val_accuracy: 0.9209
# Epoch 5/20
# 96/96 [==============================] - 1s 9ms/step - loss: 0.3623 - accuracy: 0.9455 - val_loss: 0.6574 - val_accuracy: 0.9241
# Epoch 6/20
# 96/96 [==============================] - 1s 9ms/step - loss: 0.2616 - accuracy: 0.9554 - val_loss: 0.6136 - val_accuracy: 0.9294
# Epoch 7/20
# 96/96 [==============================] - 1s 9ms/step - loss: 0.2087 - accuracy: 0.9604 - val_loss: 0.5867 - val_accuracy: 0.9298
# Epoch 8/20
# 96/96 [==============================] - 1s 8ms/step - loss: 0.1648 - accuracy: 0.9664 - val_loss: 0.5767 - val_accuracy: 0.9304
# Epoch 9/20
# 96/96 [==============================] - 1s 8ms/step - loss: 0.1349 - accuracy: 0.9707 - val_loss: 0.5244 - val_accuracy: 0.9359
# Epoch 10/20
# 96/96 [==============================] - 1s 8ms/step - loss: 0.1061 - accuracy: 0.9754 - val_loss: 0.5176 - val_accuracy: 0.9363
# Epoch 11/20
# 96/96 [==============================] - 1s 8ms/step - loss: 0.0851 - accuracy: 0.9786 - val_loss: 0.5174 - val_accuracy: 0.9398
# Epoch 12/20
# 96/96 [==============================] - 1s 8ms/step - loss: 0.0659 - accuracy: 0.9822 - val_loss: 0.5040 - val_accuracy: 0.9395
# Epoch 13/20
# 96/96 [==============================] - 1s 8ms/step - loss: 0.0558 - accuracy: 0.9840 - val_loss: 0.5117 - val_accuracy: 0.9406
# Epoch 14/20
# 96/96 [==============================] - 1s 9ms/step - loss: 0.0495 - accuracy: 0.9858 - val_loss: 0.4941 - val_accuracy: 0.9448
# Epoch 15/20
# 96/96 [==============================] - 1s 8ms/step - loss: 0.0411 - accuracy: 0.9875 - val_loss: 0.5009 - val_accuracy: 0.9424
# Epoch 16/20
# 96/96 [==============================] - 1s 8ms/step - loss: 0.0340 - accuracy: 0.9895 - val_loss: 0.4866 - val_accuracy: 0.9417
# Epoch 17/20
# 96/96 [==============================] - 1s 8ms/step - loss: 0.0261 - accuracy: 0.9919 - val_loss: 0.4995 - val_accuracy: 0.9457
# Epoch 18/20
# 96/96 [==============================] - 1s 8ms/step - loss: 0.0274 - accuracy: 0.9916 - val_loss: 0.5018 - val_accuracy: 0.9457
# Epoch 19/20
# 96/96 [==============================] - 1s 8ms/step - loss: 0.0330 - accuracy: 0.9891 - val_loss: 0.5003 - val_accuracy: 0.9452
# Epoch 20/20
# 96/96 [==============================] - 1s 8ms/step - loss: 0.0326 - accuracy: 0.9896 - val_loss: 0.4970 - val_accuracy: 0.9457

# %%
#Je l'ai ajouté
history_df = pd.DataFrame(hist.history)
history_df.loc[:, ['loss', 'val_loss']].plot();
print("Minimum validation loss: {}".format(history_df['val_loss'].min()))
# Out:
# Minimum validation loss: 0.48664796352386475

# %%
figure = plt.gcf()
figure.set_size_inches((20, 10))
plt.title('Analyse des erreurs')
plt.xlabel('Epoch')
plt.ylabel('Entropie croisée')
plt.plot(range(1, len(hist.history['loss']) + 1), hist.history['loss'])
plt.plot(range(1, len(hist.history['val_loss']) + 1), hist.history['val_loss'])
plt.legend(['Entropie croisée train', 'Entropie croisée validation'])
plt.show()

# %%
figure = plt.gcf()
figure.set_size_inches((20, 10))
plt.title('Analyse des erreurs')
plt.xlabel('Epoch')
plt.ylabel('Précision')
plt.plot(range(1, len(hist.history['accuracy']) + 1), hist.history['accuracy'])
plt.plot(range(1, len(hist.history['val_accuracy']) + 1), hist.history['val_accuracy'])
plt.legend(['Précision apprentissage', 'Précision validation'])
plt.show()
